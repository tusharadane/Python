# %%
import pandas as pd

import numpy as np

# %%
data1={"EmployeeID","FirstName","LastName","Age","Department","Position","Salary","City","JoiningDate","Experience","PerformanceScore"}

# %%
data=pd.read_csv("C:\\Users\\Prime\\Downloads\\Employee_Info_Dataset (2).csv")

# %%
data1=data.head(25)

data1
# Out:
#     EmployeeID FirstName   LastName  Age Department       Position  Salary  \
# 0            1      John        Doe   28         IT      Developer    7000
# 1            2      Jane      Smith   34         HR        Manager    8000
# 2            3       Tom      Brown   29    Finance        Analyst    6000
# 3            4      Lucy     Taylor   41         IT  Sr. Developer   10000
# 4            5      Mark    Johnson   26  Marketing      Executive    5500
# 5            6      Emma   Williams   30         IT      Developer    7200
# 6            7     Harry      Jones   32         HR        Manager    8500
# 7            8    Olivia      Davis   25    Finance        Analyst    6100
# 8            9   Michael     Miller   38         IT  Sr. Developer   10500
# 9           10    Sophia     Wilson   27  Marketing      Executive    5600
# 10          11     David      Moore   35    Finance        Analyst    6300
# ...

# %%
data2=data.tail(25)

data2
# Out:
#     EmployeeID FirstName   LastName  Age Department       Position  Salary  \
# 25          26      Ella        Lee   33         IT      Developer    7500
# 26          27      Paul     Walker   30         HR        Manager    9000
# 27          28       Zoe       Hall   22  Marketing      Executive    6000
# 28          29     Peter      Allen   44    Finance        Analyst    6700
# 29          30     Megan      Young   26         IT      Developer    7600
# 30          31     Kevin  Hernandez   41         HR        Manager    9100
# 31          32       Amy       King   34  Marketing      Executive    6100
# 32          33    George     Wright   43    Finance        Analyst    6800
# 33          34    Hannah      Lopez   23         IT  Sr. Developer   11500
# 34          35     Brian       Hill   27         HR        Manager    9200
# 35          36      Leah      Scott   32    Finance        Analyst    6300
# ...

# %%
employee_data=pd.concat([data1,data2])

employee_data
# Out:
#     EmployeeID FirstName   LastName  Age Department       Position  Salary  \
# 0            1      John        Doe   28         IT      Developer    7000
# 1            2      Jane      Smith   34         HR        Manager    8000
# 2            3       Tom      Brown   29    Finance        Analyst    6000
# 3            4      Lucy     Taylor   41         IT  Sr. Developer   10000
# 4            5      Mark    Johnson   26  Marketing      Executive    5500
# 5            6      Emma   Williams   30         IT      Developer    7200
# 6            7     Harry      Jones   32         HR        Manager    8500
# 7            8    Olivia      Davis   25    Finance        Analyst    6100
# 8            9   Michael     Miller   38         IT  Sr. Developer   10500
# 9           10    Sophia     Wilson   27  Marketing      Executive    5600
# 10          11     David      Moore   35    Finance        Analyst    6300
# ...

# %%
df=pd.concat([data1,data2],axis=1)

df
# Out:
#     EmployeeID  FirstName   LastName   Age Department       Position   Salary  \
# 0          1.0       John        Doe  28.0         IT      Developer   7000.0
# 1          2.0       Jane      Smith  34.0         HR        Manager   8000.0
# 2          3.0        Tom      Brown  29.0    Finance        Analyst   6000.0
# 3          4.0       Lucy     Taylor  41.0         IT  Sr. Developer  10000.0
# 4          5.0       Mark    Johnson  26.0  Marketing      Executive   5500.0
# 5          6.0       Emma   Williams  30.0         IT      Developer   7200.0
# 6          7.0      Harry      Jones  32.0         HR        Manager   8500.0
# 7          8.0     Olivia      Davis  25.0    Finance        Analyst   6100.0
# 8          9.0    Michael     Miller  38.0         IT  Sr. Developer  10500.0
# 9         10.0     Sophia     Wilson  27.0  Marketing      Executive   5600.0
# 10        11.0      David      Moore  35.0    Finance        Analyst   6300.0
# ...

# %%
outer_join=pd.merge(data1,data2,on="EmployeeID",how="outer")

outer_join
# Out:
#     EmployeeID FirstName_x LastName_x  Age_x Department_x     Position_x  \
# 0            1        John        Doe   28.0           IT      Developer
# 1            2        Jane      Smith   34.0           HR        Manager
# 2            3         Tom      Brown   29.0      Finance        Analyst
# 3            4        Lucy     Taylor   41.0           IT  Sr. Developer
# 4            5        Mark    Johnson   26.0    Marketing      Executive
# 5            6        Emma   Williams   30.0           IT      Developer
# 6            7       Harry      Jones   32.0           HR        Manager
# 7            8      Olivia      Davis   25.0      Finance        Analyst
# 8            9     Michael     Miller   38.0           IT  Sr. Developer
# 9           10      Sophia     Wilson   27.0    Marketing      Executive
# 10          11       David      Moore   35.0      Finance        Analyst
# 11          12       Emily     Taylor   31.0           IT      Developer
# ...

# %%
left_join=pd.merge(data1,data2,on="EmployeeID",how="left")

left_join
# Out:
#     EmployeeID FirstName_x LastName_x  Age_x Department_x     Position_x  \
# 0            1        John        Doe     28           IT      Developer
# 1            2        Jane      Smith     34           HR        Manager
# 2            3         Tom      Brown     29      Finance        Analyst
# 3            4        Lucy     Taylor     41           IT  Sr. Developer
# 4            5        Mark    Johnson     26    Marketing      Executive
# 5            6        Emma   Williams     30           IT      Developer
# 6            7       Harry      Jones     32           HR        Manager
# 7            8      Olivia      Davis     25      Finance        Analyst
# 8            9     Michael     Miller     38           IT  Sr. Developer
# 9           10      Sophia     Wilson     27    Marketing      Executive
# 10          11       David      Moore     35      Finance        Analyst
# 11          12       Emily     Taylor     31           IT      Developer
# ...

# %%
right_join=pd.merge(data1,data2,on="EmployeeID",how="right")

right_join
# Out:
#     EmployeeID FirstName_x LastName_x  Age_x Department_x Position_x  \
# 0           26         NaN        NaN    NaN          NaN        NaN
# 1           27         NaN        NaN    NaN          NaN        NaN
# 2           28         NaN        NaN    NaN          NaN        NaN
# 3           29         NaN        NaN    NaN          NaN        NaN
# 4           30         NaN        NaN    NaN          NaN        NaN
# 5           31         NaN        NaN    NaN          NaN        NaN
# 6           32         NaN        NaN    NaN          NaN        NaN
# 7           33         NaN        NaN    NaN          NaN        NaN
# 8           34         NaN        NaN    NaN          NaN        NaN
# 9           35         NaN        NaN    NaN          NaN        NaN
# 10          36         NaN        NaN    NaN          NaN        NaN
# 11          37         NaN        NaN    NaN          NaN        NaN
# 12          38         NaN        NaN    NaN          NaN        NaN
# ...

# %%
#Q4) Using iloc, select the first 10 rows and the last 2 columns of the DataFrame.

employee_data.iloc[0:11,-1:-3:-1]
# Out:
#     PerformanceScore  Experience
# 0                  4           5
# 1                  5           9
# 2                  3           4
# 3                  5          12
# 4                  2           3
# 5                  4           7
# 6                  5          10
# 7                  3           6
# 8                  5          13
# 9                  2           2
# 10                 4           8

# %%
employee_data.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'LastName', 'Age', 'Department', 'Position',
#        'Salary', 'City', 'JoiningDate', 'Experience', 'PerformanceScore'],
#       dtype='object')

# %%
#Q5) Using loc, select the rows for employees who are in the "IT" department and display only their FirstName, Position, and Salary.

employee_data.loc[employee_data["Department"]== 'IT',["FirstName","Position","Salary","Department"]]
# Out:
#    FirstName       Position  Salary Department
# 0       John      Developer    7000         IT
# 3       Lucy  Sr. Developer   10000         IT
# 5       Emma      Developer    7200         IT
# 8    Michael  Sr. Developer   10500         IT
# 11     Emily      Developer    7100         IT
# 15       Ava      Developer    7400         IT
# 18    Robert  Sr. Developer   11000         IT
# 21      Lily      Developer    7300         IT
# 25      Ella      Developer    7500         IT
# 29     Megan      Developer    7600         IT
# 33    Hannah  Sr. Developer   11500         IT
# 36     Jacob      Developer    7200         IT
# 39   Natalie  Sr. Developer   12000         IT
# 43     Alice      Developer    7000         IT
# 47      Anna      Developer    9800         IT

# %%
#Q6) Count the number of employees in each department using value_counts.

employee_data["Department"].value_counts()
# Out:
# Department
# IT           15
# Finance      13
# HR           11
# Marketing    11
# Name: count, dtype: int64

# %%
#Q7) Sort the DataFrame by Salary in descending order and display the last 5 salaries.

employee_data.sort_values(by='Salary',ascending=False).head(5)
# Out:
#     EmployeeID FirstName  LastName  Age Department       Position  Salary  \
# 39          40   Natalie  Gonzalez   31         IT  Sr. Developer   12000
# 33          34    Hannah     Lopez   23         IT  Sr. Developer   11500
# 18          19    Robert  Thompson   45         IT  Sr. Developer   11000
# 8            9   Michael    Miller   38         IT  Sr. Developer   10500
# 3            4      Lucy    Taylor   41         IT  Sr. Developer   10000
#
#         City JoiningDate  Experience  PerformanceScore
# 39  Banglore  2016-02-22           8                 3
# 33  Banglore  2011-02-21          13                 5
# 18  Banglore  2010-02-05          14                 5
# 8   Banglore  2011-05-10          13                 5
# 3   Banglore  2012-04-01          12                 5

# %%
#Q8) Group the data by Department and calculate the total salary expenditure for each department.

employee_data.groupby('Department')['Salary'].sum().reset_index()
# Out:
#   Department  Salary
# 0    Finance   84400
# 1         HR   93300
# 2         IT  130100
# 3  Marketing   69800

# %%
#Q9) Group the data by City and Position to find the average salary in each position across different cities.

employee_data.groupby(['City','Position'])['Salary'].mean().reset_index()
# Out:
#         City       Position        Salary
# 0   Banglore  Sr. Developer  11000.000000
# 1    Chennai        Analyst   6492.307692
# 2      Delhi        Manager   8481.818182
# 3  Hyderabad      Executive   6345.454545
# 4     Mumbai      Developer   7510.000000

# %%
#Q10) Filter out all employees with a PerformanceScore of 3 or below.

employee_data[employee_data['PerformanceScore'] <= 3 ]
# Out:
#     EmployeeID FirstName   LastName  Age Department       Position  Salary  \
# 2            3       Tom      Brown   29    Finance        Analyst    6000
# 4            5      Mark    Johnson   26  Marketing      Executive    5500
# 7            8    Olivia      Davis   25    Finance        Analyst    6100
# 9           10    Sophia     Wilson   27  Marketing      Executive    5600
# 13          14     Chloe     Thomas   24  Marketing      Executive    5700
# 14          15     Chris    Jackson   33    Finance        Analyst    6200
# 17          18       Mia     Martin   29    Finance        Analyst    6500
# 19          20  Isabella     Garcia   30  Marketing      Executive    5800
# 23          24     Grace  Rodriguez   31  Marketing      Executive    5900
# 24          25    Andrew      Lewis   42    Finance        Analyst    6600
# 27          28       Zoe       Hall   22  Marketing      Executive    6000
# ...

# %%
#Q11) Find all employees whose Position starts with the letter "S".

employee_data[employee_data['Position'].str.startswith('S')]
# Out:
#     EmployeeID FirstName  LastName  Age Department       Position  Salary  \
# 3            4      Lucy    Taylor   41         IT  Sr. Developer   10000
# 8            9   Michael    Miller   38         IT  Sr. Developer   10500
# 18          19    Robert  Thompson   45         IT  Sr. Developer   11000
# 33          34    Hannah     Lopez   23         IT  Sr. Developer   11500
# 39          40   Natalie  Gonzalez   31         IT  Sr. Developer   12000
#
#         City JoiningDate  Experience  PerformanceScore
# 3   Banglore  2012-04-01          12                 5
# 8   Banglore  2011-05-10          13                 5
# 18  Banglore  2010-02-05          14                 5
# 33  Banglore  2011-02-21          13                 5
# 39  Banglore  2016-02-22           8                 3

# %%
#Q12) Create a new column Updated_Salary by increasing each employee's current Salary by 10%.

employee_data['Updated_salary']=employee_data['Salary']*1.10

employee_data
# Out:
#     EmployeeID FirstName   LastName  Age Department       Position  Salary  \
# 0            1      John        Doe   28         IT      Developer    7000
# 1            2      Jane      Smith   34         HR        Manager    8000
# 2            3       Tom      Brown   29    Finance        Analyst    6000
# 3            4      Lucy     Taylor   41         IT  Sr. Developer   10000
# 4            5      Mark    Johnson   26  Marketing      Executive    5500
# 5            6      Emma   Williams   30         IT      Developer    7200
# 6            7     Harry      Jones   32         HR        Manager    8500
# 7            8    Olivia      Davis   25    Finance        Analyst    6100
# 8            9   Michael     Miller   38         IT  Sr. Developer   10500
# 9           10    Sophia     Wilson   27  Marketing      Executive    5600
# 10          11     David      Moore   35    Finance        Analyst    6300
# ...

# %%
#Q13) Drop the Experience column from the DataFrame.

employee_data.drop(columns=['Experience'])
# Out:
#     EmployeeID FirstName   LastName  Age Department       Position  Salary  \
# 0            1      John        Doe   28         IT      Developer    7000
# 1            2      Jane      Smith   34         HR        Manager    8000
# 2            3       Tom      Brown   29    Finance        Analyst    6000
# 3            4      Lucy     Taylor   41         IT  Sr. Developer   10000
# 4            5      Mark    Johnson   26  Marketing      Executive    5500
# 5            6      Emma   Williams   30         IT      Developer    7200
# 6            7     Harry      Jones   32         HR        Manager    8500
# 7            8    Olivia      Davis   25    Finance        Analyst    6100
# 8            9   Michael     Miller   38         IT  Sr. Developer   10500
# 9           10    Sophia     Wilson   27  Marketing      Executive    5600
# 10          11     David      Moore   35    Finance        Analyst    6300
# ...

# %%
#Q14) Column Addition: Add a new column to the dataset that calculates the number of years an employee has been with the company based on their
#joining date.

employee_data['JoiningDate']= pd.to_datetime(employee_data['JoiningDate'])


employee_data['Year_with_company']= (datetime.now()-employee_data['JoiningDate']).dt.days / 365.25
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[242], line 7
#       1 #Q14) Column Addition: Add a new column to the dataset that calculates the number of years an employee has been with the company based on their
#       2 #joining date.
#       4 employee_data['JoiningDate']= pd.to_datetime(employee_data['JoiningDate'])
# ----> 7 employee_data['Year_with_company']= (dt.now()-employee_data['JoiningDate']).dt.days / 365.25
#
# NameError: name 'dt' is not defined

# %%
employee_data["CurrentTImestamp"] = pd.Timestamp.today()

# %%
employee_data.head()
# Out:
#    EmployeeID FirstName LastName  Age Department       Position  Salary  \
# 0           1      John      Doe   28         IT      Developer    7000
# 1           2      Jane    Smith   34         HR        Manager    8000
# 2           3       Tom    Brown   29    Finance        Analyst    6000
# 3           4      Lucy   Taylor   41         IT  Sr. Developer   10000
# 4           5      Mark  Johnson   26  Marketing      Executive    5500
#
#         City JoiningDate  Experience  PerformanceScore  \
# 0     Mumbai  2018-06-15           5                 4
# 1      Delhi  2015-07-20           9                 5
# 2    Chennai  2019-03-12           4                 3
# 3   Banglore  2012-04-01          12                 5
# 4  Hyderabad  2020-09-10           3                 2
#
#             CurrentTImestamp
# 0 2024-09-25 13:08:30.362795
# 1 2024-09-25 13:08:30.362795
# 2 2024-09-25 13:08:30.362795
# 3 2024-09-25 13:08:30.362795
# 4 2024-09-25 13:08:30.362795

# %%
employee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        50 non-null     int64
#  1   FirstName         50 non-null     object
#  2   LastName          50 non-null     object
#  3   Age               50 non-null     int64
#  4   Department        50 non-null     object
#  5   Position          50 non-null     object
#  6   Salary            50 non-null     int64
#  7   City              50 non-null     object
#  8   JoiningDate       50 non-null     object
#  9   Experience        50 non-null     int64
#  10  PerformanceScore  50 non-null     int64
#  11  CurrentTImestamp  50 non-null     datetime64[us]
# dtypes: datetime64[us](1), int64(5), object(6)
# memory usage: 4.8+ KB

# %%
employee_data["JoiningDate"] = pd.to_datetime(employee_data["JoiningDate"])

# %%
employee_data["Employee_Tenure"] = (employee_data["CurrentTImestamp"].dt.year) - (employee_data["JoiningDate"].dt.year)
employee_data
# Out:
#     EmployeeID FirstName   LastName  Age Department       Position  Salary  \
# 0            1      John        Doe   28         IT      Developer    7000
# 1            2      Jane      Smith   34         HR        Manager    8000
# 2            3       Tom      Brown   29    Finance        Analyst    6000
# 3            4      Lucy     Taylor   41         IT  Sr. Developer   10000
# 4            5      Mark    Johnson   26  Marketing      Executive    5500
# 5            6      Emma   Williams   30         IT      Developer    7200
# 6            7     Harry      Jones   32         HR        Manager    8500
# 7            8    Olivia      Davis   25    Finance        Analyst    6100
# 8            9   Michael     Miller   38         IT  Sr. Developer   10500
# 9           10    Sophia     Wilson   27  Marketing      Executive    5600
# 10          11     David      Moore   35    Finance        Analyst    6300
# ...

# %%
#Q15) Calculate the average salary of employees in each department

employee_data.groupby('Department')['Salary'].median().reset_index()
# Out:
#   Department  Salary
# 0    Finance  6500.0
# 1         HR  8700.0
# 2         IT  7500.0
# 3  Marketing  6000.0

# %%
#Q16) Count the number of employees in each city.

employee_data.groupby('City')['EmployeeID'].count()
# Out:
# City
# Banglore      5
# Chennai      13
# Delhi        11
# Hyderabad    11
# Mumbai       10
# Name: EmployeeID, dtype: int64

# %%
#Q17) Identify the employees who have been with the company the longest.


longest_employee_with_company = employee_data.sort_values(by='JoiningDate')

longest_employee_with_company.head(5)
# Out:
#     EmployeeID FirstName  LastName  Age Department       Position  Salary  \
# 32          33    George    Wright   43    Finance        Analyst    6800
# 18          19    Robert  Thompson   45         IT  Sr. Developer   11000
# 38          39     Ethan     Baker   46    Finance        Analyst    6900
# 33          34    Hannah     Lopez   23         IT  Sr. Developer   11500
# 8            9   Michael    Miller   38         IT  Sr. Developer   10500
#
#         City JoiningDate  Experience  PerformanceScore  Updated_salary
# 32   Chennai  2010-01-13          14                 4          7480.0
# 18  Banglore  2010-02-05          14                 5         12100.0
# 38   Chennai  2010-11-19          15                 5          7590.0
# 33  Banglore  2011-02-21          13                 5         12650.0
# 8   Banglore  2011-05-10          13                 5         11550.0

# %%
employee_data.var(numeric_only=True)
# Out:
# EmployeeID          2.125000e+02
# Age                 5.429429e+01
# Salary              2.627445e+06
# Experience          1.183837e+01
# PerformanceScore    1.030612e+00
# dtype: float64

# %%
employee_data.cov(numeric_only=True)
# Out:
#                    EmployeeID          Age        Salary   Experience  \
# EmployeeID         212.500000    26.112245  3.159184e+03     8.857143
# Age                 26.112245    54.294286  2.350939e+03    11.090612
# Salary            3159.183673  2350.938776  2.627445e+06  3134.122449
# Experience           8.857143    11.090612  3.134122e+03    11.838367
# PerformanceScore     0.806122     2.728571  7.481633e+02     2.436735
#
#                   PerformanceScore
# EmployeeID                0.806122
# Age                       2.728571
# Salary                  748.163265
# Experience                2.436735
# PerformanceScore          1.030612

# %%
employee_data.corr(numeric_only=True)
# Out:
#                   EmployeeID       Age    Salary  Experience  PerformanceScore
# EmployeeID          1.000000  0.243102  0.133699    0.176591          0.054472
# Age                 0.243102  1.000000  0.196833    0.437454          0.364763
# Salary              0.133699  0.196833  1.000000    0.561957          0.454655
# Experience          0.176591  0.437454  0.561957    1.000000          0.697613
# PerformanceScore    0.054472  0.364763  0.454655    0.697613          1.000000

# %%
employee_data.std(numeric_only=True)
# Out:
# EmployeeID            14.577380
# Age                    7.368466
# Salary              1620.939511
# Experience             3.440693
# PerformanceScore       1.015191
# dtype: float64
